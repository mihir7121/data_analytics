# %%
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
combine = [train, test]

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train[['Pclass','Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# As we see that lower class people have survived really less, then the middle class and then the upper class.
#
# Lower class (Pclass = 3): Only 24% people have survived
#
# Middle class (Pclass = 2): Only 47% people survived
#
# Upper class(Pclass = 1): 63% people survived

# %%
train[['Sex','Survived']].groupby(['Sex'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# We can conclude from the above that females were given priority over male passengers.
#
# 74% female survived whereas only 19% male survived.
#
# Also, we can conclude that gender has the highest effect to the survival correlation

# %%
data = train.corr()
sns.heatmap(data, cmap='Greens', annot=True)

# %%
train[['Pclass','Sex','Survived']].groupby(['Sex','Pclass'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %% [markdown]
# Here we can reaffirm our previous conclusions and combine them. We can see that females had the least deaths, and in that, upper class females had the least deaths.
#
# Hence, **females** were given priority over male and upper class people were given priority over middle and lower class. Based on this, we can say that being a woman was almost a gurantee of survival for the first 2 classes(90%>), whereas it was 50-50 for the lower class females
#
# **In males**, the lower and middle class had only about 15% chances of survival whereas the men of upper class had almost double the chances of survival(36%)

# %%
# mean_value = train['Age'].mean()
# #Replace NaN values by the mean value of age
# #train['Age'].fillna(value=mean_value, inplace=True)

# bins= [0,11,18,50,100]
# labels = ['Infant','Kid','Adult','Senior Citizen']
# train['AgeGroup'] = pd.cut(train['Age'], bins=bins, labels=labels, right=False)
# print(train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# train['AgeGroup'].describe()
# Out:
# count       891
# unique        4
# top       Adult
# freq        704
# Name: AgeGroup, dtype: object

# %%
# train[['AgeGroup','Survived']].groupby(['AgeGroup'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#                 Survived
# AgeGroup
# Infant          0.593750
# Kid             0.469388
# Senior Citizen  0.364865
# Adult           0.360795

# %%
# categorical_age = train[['AgeGroup','Survived']].groupby(['AgeGroup'], as_index=True).mean()
# sns.lineplot(data=categorical_age)

# %% [markdown]
# After doing EDA on the age column, we can say that Infants and kids were given higher priority compared to adults/senior citizens. However, the number of adults are far more (704/891) we can say that the data is biased and hence age cannot be used as a factor to conclude if the person has survived or not

# %% [markdown]
# So far, we have concluded that *sex* and *class* are important features, whereas age is not. Now, we move on to the further features

# %%
train[['Embarked','Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
#C = Cherbourg, Q = Queenstown, S = Southampton
train[['Sex', 'Embarked','Survived']].groupby(['Sex', 'Embarked'], as_index=True).mean().sort_values(by='Survived', ascending = False)
# Out:
#                  Survived
# Sex    Embarked
# female C         0.876712
#        Q         0.750000
#        S         0.689655
# male   C         0.305263
#        S         0.174603
#        Q         0.073171

# %% [markdown]
# We can see above that the survival rates are clearly different for different sex entering from different ports
#
# Ones entering through Queenstown has the least survival rate and ones entering through Cherboug has highest survival rate. This rate also differs according to gender.

# %%
train[['Sex', 'Embarked','PassengerId']].groupby(['Embarked', 'Sex'], as_index=True).count().sort_values(by='Embarked', ascending = True)
# Out:
#                  PassengerId
# Embarked Sex
# C        female           73
#          male             95
# Q        female           36
#          male             41
# S        female          203
#          male            441

# %% [markdown]
# From the above we can say that the data is a little inconsistent and biased when sliced with respect to the number of passengers. We can, for now, keep the data, but we have to later remove it if it harms the model more than improving.

# %%
sib_sp = train[["SibSp", "Survived"]].groupby(['SibSp'], as_index=True).mean().sort_values(by='Survived', ascending=False)
sns.lineplot(data=sib_sp, x='SibSp', y='Survived')

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

family_size = train[['FamilySize','Sex', 'Survived']].groupby(['Sex','FamilySize'], as_index=True).mean()
sns.lineplot(data=family_size, x='FamilySize', y='Survived')

# %%
sns.lineplot(data=family_size, x='FamilySize', y='Survived', hue='Sex')

# %%
train[['FamilySize', 'PassengerId']].groupby(['FamilySize'], as_index=True).count()
# Out:
#             PassengerId
# FamilySize
# 1                   537
# 2                   161
# 3                   102
# 4                    29
# 5                    15
# 6                    22
# 7                    12
# 8                     6
# 11                    7

# %% [markdown]
# From the above graph, we can conclude that having a small family (2,3) people has the highest survival rate whereas, having a large family reduces the survival rate.
#
# Further, both the features work against each other because they both are dependent and affect the result in a similar way.

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=True).mean()
# Out:
#          Survived
# IsAlone
# 0        0.505650
# 1        0.303538

# %%
train[['IsAlone','Sex', 'Survived']].groupby(['Sex','IsAlone'], as_index=True).mean()
# Out:
#                 Survived
# Sex    IsAlone
# female 0        0.712766
#        1        0.785714
# male   0        0.271084
#        1        0.155718

# %%
train = train.drop(['Parch', 'SibSp', 'IsAlone'], axis=1)
test = test.drop(['Parch', 'SibSp', 'IsAlone'], axis=1)
combine = [train, test]

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           2
# 1          PC 17599  71.2833   C85        C           2
# 2  STON/O2. 3101282   7.9250   NaN        S           1
# 3            113803  53.1000  C123        S           2
# 4            373450   8.0500   NaN        S           1

# %%
for dataset in combine:
    dataset['CategoricalAge'] = pd.qcut(train['Age'], 5)

categorical_age = train[['CategoricalAge', 'Survived']].groupby(['CategoricalAge'], as_index=True).mean()
print(categorical_age)
# Out:
#                 Survived
# CategoricalAge
# (0.419, 19.0]   0.481707
# (19.0, 25.0]    0.328467
# (25.0, 31.8]    0.393701
# (31.8, 41.0]    0.437500
# (41.0, 80.0]    0.373239

# %%
for dataset in combine:
    dataset['CategoricalAge'] = pd.qcut(train['Age'], 15)

train[['CategoricalAge', 'Survived']].groupby(['CategoricalAge'], as_index=True).mean()
# Out:
#                 Survived
# CategoricalAge
# (0.419, 7.0]    0.680000
# (7.0, 16.0]     0.420000
# (16.0, 19.0]    0.375000
# (19.0, 21.0]    0.200000
# (21.0, 23.0]    0.380952
# (23.0, 25.0]    0.381818
# (25.0, 27.0]    0.472222
# (27.0, 29.0]    0.319149
# (29.0, 31.8]    0.409091
# (31.8, 34.0]    0.440000
# (34.0, 37.0]    0.479167
# (37.0, 41.0]    0.391304
# (41.0, 47.0]    0.301887
# (47.0, 54.0]    0.510638
# (54.0, 80.0]    0.309524

# %%
categorical_age = train[['CategoricalAge', 'Survived']].groupby(['CategoricalAge'], as_index=False).mean()
sns.lineplot(data=categorical_age)

# %%
for dataset in combine:
    dataset['IsKid'] = 0
    dataset.loc[dataset['Age'] <= 7, 'IsKid'] = 1

print(train[['IsKid', 'Survived']].groupby(['IsKid'], as_index=False).mean())
# Out:
#    IsKid  Survived
# 0      0  0.366231
# 1      1  0.680000

# %%
#We drop the ticket column because it makes it difficult to predict because of over 700 unique values
train = train.drop(['Ticket'], axis=1)
test = test.drop(['Ticket'], axis=1)
combine = [train, test]

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#   Cabin Embarked  FamilySize CategoricalAge  IsKid
# 0   NaN        S           2   (21.0, 23.0]      0
# 1   C85        C           2   (37.0, 41.0]      0
# 2   NaN        S           1   (25.0, 27.0]      0
# 3  C123        S           2   (34.0, 37.0]      0
# ...

# %%
train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#for cabin, we check if the person has a cabin or not and check its relation with survival
for dataset in combine:
    dataset['HasCabin'] = 1
    dataset.loc[dataset['Cabin'].isnull(), 'HasCabin'] = 0

train[['HasCabin', 'Survived']].groupby(['HasCabin'], as_index=True).mean()
# Out:
#           Survived
# HasCabin
# 0         0.299854
# 1         0.666667

# %% [markdown]
# As we can see that having a cabin doubles the chances of survival, hence instead of cabin numbers we will keep if the person has cabin or does not have cabin

# %%
train = train.drop(['Cabin'], axis=1)
test = test.drop(['Cabin'], axis=1)
combine = [train, test]

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#   Embarked  FamilySize CategoricalAge  IsKid  HasCabin
# 0        S           2   (21.0, 23.0]      0         0
# 1        C           2   (37.0, 41.0]      0         1
# 2        S           1   (25.0, 27.0]      0         0
# 3        S           2   (34.0, 37.0]      0         1
# ...

# %%
sns.boxplot(data=train, x='Pclass', y='Fare', hue='Survived')

# %%
train = train.drop(['Name', 'PassengerId'], axis=1)
test = test.drop(['Name'], axis=1)
combine = [train, test]
train.shape, test.shape
# Out:
# ((891, 10), (418, 9))

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

'''train['Title'] = train['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

train['Title'] = train['Title'].replace('Mlle', 'Miss')
train['Title'] = train['Title'].replace('Ms', 'Miss')
train['Title'] = train['Title'].replace('Mme', 'Mrs')'''
    
train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
train[['Title', 'Pclass', 'Survived']].groupby(['Title', 'Pclass'], as_index=False).mean()
# Out:
#      Title  Pclass  Survived
# 0   Master       1  1.000000
# 1   Master       2  1.000000
# 2   Master       3  0.392857
# 3     Miss       1  0.958333
# 4     Miss       2  0.942857
# 5     Miss       3  0.500000
# 6       Mr       1  0.345794
# 7       Mr       2  0.087912
# 8       Mr       3  0.112853
# 9      Mrs       1  0.976744
# 10     Mrs       2  0.902439
# 11     Mrs       3  0.500000
# 12    Rare       1  0.533333
# 13    Rare       2  0.000000

# %%
train.loc[train['Age'].isnull()].groupby(['Title'], as_index=False).count()
# Out:
#     Title  PassengerId  Survived  Pclass  Name  Sex  Age  Fare  Embarked  \
# 0  Master            4         4       4     4    4    0     4         4
# 1    Miss           36        36      36    36   36    0    36        36
# 2      Mr          119       119     119   119  119    0   119       119
# 3     Mrs           17        17      17    17   17    0    17        17
# 4    Rare            1         1       1     1    1    0     1         1
#
#    FamilySize  CategoricalAge  IsKid  HasCabin
# 0           4               0      4         4
# 1          36               0     36        36
# 2         119               0    119       119
# 3          17               0     17        17
# 4           1               0      1         1

# %%
pd.crosstab(train['Title'], train['CategoricalAge'])
# Out:
# CategoricalAge  (0.419, 7.0]  (7.0, 16.0]  (16.0, 19.0]  (19.0, 21.0]  \
# Title
# Master                    26           10             0             0
# Miss                      24           23            19             9
# Mr                         0           15            38            31
# Mrs                        0            2             7             0
# Rare                       0            0             0             0
#
# CategoricalAge  (21.0, 23.0]  (23.0, 25.0]  (25.0, 27.0]  (27.0, 29.0]  \
# Title
# Master                     0             0             0             0
# Miss                      13            11             6             4
# Mr                        24            34            24            32
# Mrs                        4            10             5            10
# Rare                       1             0             1             1
#
# CategoricalAge  (29.0, 31.8]  (31.8, 34.0]  (34.0, 37.0]  (37.0, 41.0]  \
# Title
# ...

# %%
train.groupby(['Title'], as_index=False).count()
# Out:
#     Title  PassengerId  Survived  Pclass  Name  Sex  Age  Fare  Embarked  \
# 0  Master           40        40      40    40   40   36    40        40
# 1    Miss          185       185     185   185  185  149   185       184
# 2      Mr          517       517     517   517  517  398   517       517
# 3     Mrs          126       126     126   126  126  109   126       125
# 4    Rare           23        23      23    23   23   22    23        23
#
#    FamilySize  CategoricalAge  IsKid  HasCabin
# 0          40              36     40        40
# 1         185             149    185       185
# 2         517             398    517       517
# 3         126             109    126       126
# 4          23              22     23        23

# %% [markdown]
# We have 185 "Miss" appearances, being 149 with age and 36 with missing age feature. From those 149 misses, 24 are kids (younger than 7), roughly 16%. That figure will be important when we correct the IsKid feature.
#
# We can try to predict IsKid using the Title feature. All Masters are kids and a proportional quantity of Misses are going to be kids. None of the Mr's, Mrs's and Rare's are kids.

# %%
train.loc[train['Title'] == 'Master']
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 78            79         1       2
# 125          126         1       3
# 159          160         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 176          177         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# ...

# %%
for dataset in combine:
    #missing_age = dataset.loc[dataset['Age'].isnull()]
    dataset.loc[dataset['Title'] == 'Master', 'IsKid'] = 1
    
train.loc[train['Title'] == 'Master']
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 78            79         1       2
# 125          126         1       3
# 159          160         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 176          177         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# ...

# %%
train = train.drop(['Name', 'PassengerId'], axis=1)
test = test.drop(['Name'], axis=1)
combine = [train, test]
train.shape, test.shape
# Out:
# ((891, 11), (418, 11))

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare Embarked  FamilySize CategoricalAge  \
# 0         0       3    0  22.0   7.2500        S           2   (21.0, 23.0]
# 1         1       1    1  38.0  71.2833        C           2   (37.0, 41.0]
# 2         1       3    1  26.0   7.9250        S           1   (25.0, 27.0]
# 3         1       1    1  35.0  53.1000        S           2   (34.0, 37.0]
# 4         0       3    0  35.0   8.0500        S           1   (34.0, 37.0]
#
#    IsKid  HasCabin Title
# 0      0         0    Mr
# 1      0         1   Mrs
# 2      0         0  Miss
# 3      0         1   Mrs
# 4      0         0    Mr

# %%
freq_port = train.Embarked.dropna().mode()[0]

for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare Embarked  FamilySize CategoricalAge  \
# 0         0       3    0  22.0   7.2500        S           2   (21.0, 23.0]
# 1         1       1    1  38.0  71.2833        C           2   (37.0, 41.0]
# 2         1       3    1  26.0   7.9250        S           1   (25.0, 27.0]
# 3         1       1    1  35.0  53.1000        S           2   (34.0, 37.0]
# 4         0       3    0  35.0   8.0500        S           1   (34.0, 37.0]
#
#    IsKid  HasCabin Title
# 0      0         0    Mr
# 1      0         1   Mrs
# 2      0         0  Miss
# 3      0         1   Mrs
# 4      0         0    Mr

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare  Embarked  FamilySize CategoricalAge  \
# 0         0       3    0  22.0   7.2500         0           2   (21.0, 23.0]
# 1         1       1    1  38.0  71.2833         1           2   (37.0, 41.0]
# 2         1       3    1  26.0   7.9250         0           1   (25.0, 27.0]
# 3         1       1    1  35.0  53.1000         0           2   (34.0, 37.0]
# 4         0       3    0  35.0   8.0500         0           1   (34.0, 37.0]
#
#    IsKid  HasCabin Title
# 0      0         0    Mr
# 1      0         1   Mrs
# 2      0         0  Miss
# 3      0         1   Mrs
# 4      0         0    Mr

# %%
train = train.drop(['Age', 'Fare', 'CategoricalAge', 'Title'], axis=1)
test = test.drop(['Age', 'Fare', 'CategoricalAge', 'Title'], axis=1)
combine = [train, test]
train.shape, test.shape
# Out:
# ((891, 7), (418, 7))

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Embarked  FamilySize  IsKid  HasCabin
# 0         0       3    0         0           2      0         0
# 1         1       1    1         1           2      0         1
# 2         1       3    1         0           1      0         0
# 3         1       1    1         0           2      0         1
# 4         0       3    0         0           1      0         0

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Embarked  FamilySize  IsKid  HasCabin
# 0          892       3    0         2           1      0         0
# 1          893       3    1         0           2      0         0
# 2          894       2    0         2           1      0         0
# 3          895       3    0         0           1      0         0
# 4          896       3    1         0           3      0         0

# %%
X_train = train.drop("Survived", axis=1)
Y_train = train["Survived"]
X_test  = test.drop("PassengerId", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 6), (891,), (418, 6))

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 82.38

# %%
coeff_df = pd.DataFrame(train.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#       Feature  Correlation
# 1         Sex     2.875768
# 4       IsKid     2.604359
# 5    HasCabin     0.575597
# 2    Embarked     0.235839
# 3  FamilySize    -0.332492
# 0      Pclass    -0.818679

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree
# Out:
# 85.52

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest
# Out:
# 85.52

# %%
output = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": Y_pred
    })

output.to_csv('submission.csv', index=False)
